# %%
import pandas as pd

df1 = pd.read_csv("series 4 result.csv")
df2 = pd.read_csv("NH3 protease result.csv")
df3 = pd.read_csv("EGFR small result.csv")

print("Series4:", df1.columns)
print("NH3:", df2.columns)
print("EGFR:", df3.columns)
# Out:
# Series4: Index(['Task', 'Mean auc', 'Standard deviation auc', 'Fold 0 auc',
#        'Fold 1 auc', 'Fold 2 auc', 'Fold 3 auc', 'Fold 4 auc', 'Mean prc-auc',
#        'Standard deviation prc-auc', 'Fold 0 prc-auc', 'Fold 1 prc-auc',
#        'Fold 2 prc-auc', 'Fold 3 prc-auc', 'Fold 4 prc-auc', 'Mean accuracy',
#        'Standard deviation accuracy', 'Fold 0 accuracy', 'Fold 1 accuracy',
#        'Fold 2 accuracy', 'Fold 3 accuracy', 'Fold 4 accuracy'],
#       dtype='object')
# NH3: Index(['Task', 'Mean auc', 'Standard deviation auc', 'Fold 0 auc',
#        'Fold 1 auc', 'Fold 2 auc', 'Fold 3 auc', 'Fold 4 auc', 'Mean prc-auc',
#        'Standard deviation prc-auc', 'Fold 0 prc-auc', 'Fold 1 prc-auc',
#        'Fold 2 prc-auc', 'Fold 3 prc-auc', 'Fold 4 prc-auc', 'Mean accuracy',
#        'Standard deviation accuracy', 'Fold 0 accuracy', 'Fold 1 accuracy',
#        'Fold 2 accuracy', 'Fold 3 accuracy', 'Fold 4 accuracy'],
#       dtype='object')
# ...
